# %% [markdown]
# ## Segundo Examen Parcial  de Estadística Aplicada
# Enero-Junio 2023

# %% [markdown]
# **Nombre:** Alan Fernando Del Real Almaguer
#
# **Matricula:** 1918760

# %% [markdown]
# **Instrucciones:** En cada punto importa las librerias que consideres necesarias

# %%
# Importa las librerias de numpy, python y matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# importa la base de datos llamada credit_risk.csv
# https://raw.githubusercontent.com/jimmyzac/Estadistica-Aplicada-FCFM-UANL/main/bases_datos/credit_risk.csv
base=pd.read_csv("https://raw.githubusercontent.com/jimmyzac/Estadistica-Aplicada-FCFM-UANL/main/bases_datos/credit_risk.csv")
base
# Out:
#     checking_account_status  duration        credit_history  \
# 0                   below_0         6      critical_account
# 1                  0_to_200        48  existing_credit_paid
# 2                no_account        12      critical_account
# 3                   below_0        42  existing_credit_paid
# 4                   below_0        24       delay_in_paying
# ..                      ...       ...                   ...
# 995              no_account        12  existing_credit_paid
# 996                 below_0        30  existing_credit_paid
# 997              no_account        12  existing_credit_paid
# 998                 below_0        45  existing_credit_paid
# 999                0_to_200        45      critical_account
#
#                  purpose  amount savings_account_status employment_years  \
# 0               radio_TV    1169                unknown          above_7
# 1               radio_TV    5951              below_100      between_1_4
# ...

# %% [markdown]
# La base de datos es la información proporcionada por un banco donde nos muestra el tiempo que transcurre desde que un cliente pide un préstamo hasta que lo paga completamente (evento)
#
# a continuación se muestran la descripción de la base de datos

# %% [markdown]
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-fymr{border-color:inherit;font-weight:bold;text-align:left;vertical-align:top}
# .tg .tg-0pky{border-color:inherit;text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-fymr">   <br>Característica   </th>
#     <th class="tg-fymr">   <br>Variable   </th>
#     <th class="tg-fymr">   <br>Tipo   </th>
#     <th class="tg-fymr">   <br>Descripción   </th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0pky">   <br>Time   </td>
#     <td class="tg-0pky">   <br>duration   </td>
#     <td class="tg-0pky">   <br>numerical   </td>
#     <td class="tg-0pky">   <br>Duration in month   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Event   </td>
#     <td class="tg-0pky">   <br>full_repaid   </td>
#     <td class="tg-0pky">   <br>categorical   </td>
#     <td class="tg-0pky">   <br>Specifies if the loan was fully   repaid   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Socio-Demographic   </td>
#     <td class="tg-0pky">   <br>age   </td>
#     <td class="tg-0pky">   <br>numerical   </td>
#     <td class="tg-0pky">   <br>Age of the borrower (in years)   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Socio-Demographic   </td>
#     <td class="tg-0pky">   <br>foreign_worker   </td>
#     <td class="tg-0pky">   <br>numerical   </td>
#     <td class="tg-0pky">   <br>Indicates if the borrower is a   foreign worker   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Socio-Demographic   </td>
#     <td class="tg-0pky">   <br>personal_status   </td>
#     <td class="tg-0pky">   <br>categorical   </td>
#     <td class="tg-0pky">   <br>Gender and Marital status   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Socio-Demographic   </td>
#     <td class="tg-0pky">   <br>people_liable   </td>
#     <td class="tg-0pky">   <br>numerical   </td>
#     <td class="tg-0pky">   <br>Number of people being liable to   provide maintenance for   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Socio-Demographic   </td>
#     <td class="tg-0pky">   <br>telephone   </td>
#     <td class="tg-0pky">   <br>numerical   </td>
#     <td class="tg-0pky">   <br>Indicates if the borrower owns a   phone   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Employment   </td>
#     <td class="tg-0pky">   <br>employment_years   </td>
#     <td class="tg-0pky">   <br>categorical   </td>
#     <td class="tg-0pky">   <br>Years of employment at current job   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Employment   </td>
#     <td class="tg-0pky">   <br>job   </td>
#     <td class="tg-0pky">   <br>categorical   </td>
#     <td class="tg-0pky">   <br>Employment status   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Residence   </td>
#     <td class="tg-0pky">   <br>housing   </td>
#     <td class="tg-0pky">   <br>categorical   </td>
#     <td class="tg-0pky">   <br>Residential status of the borrower   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Residence   </td>
#     <td class="tg-0pky">   <br>present_residence   </td>
#     <td class="tg-0pky">   <br>numerical   </td>
#     <td class="tg-0pky">   <br>Years living at current residence   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Loan   information   </td>
#     <td class="tg-0pky">   <br>amount   </td>
#     <td class="tg-0pky">   <br>numerical   </td>
#     <td class="tg-0pky">   <br>Amount of money borrowed   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Loan   information   </td>
#     <td class="tg-0pky">   <br>installment_rate   </td>
#     <td class="tg-0pky">   <br>numerical   </td>
#     <td class="tg-0pky">   <br>Percentage of amount borrowed that   will be charged by a lender to a borrower.   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Loan   information   </td>
#     <td class="tg-0pky">   <br>purpose   </td>
#     <td class="tg-0pky">   <br>categorical   </td>
#     <td class="tg-0pky">   <br>Reason to get a loan   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Bank   information   </td>
#     <td class="tg-0pky">   <br>checking_account_status   </td>
#     <td class="tg-0pky">   <br>categorical   </td>
#     <td class="tg-0pky">   <br>Status of the checking account   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Bank   information   </td>
#     <td class="tg-0pky">   <br>credit_history   </td>
#     <td class="tg-0pky">   <br>categorical   </td>
#     <td class="tg-0pky">   <br>Credit history of the borrower   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Bank   information   </td>
#     <td class="tg-0pky">   <br>number_of_credits   </td>
#     <td class="tg-0pky">   <br>numerical   </td>
#     <td class="tg-0pky">   <br>Number of existing credits at this   bank   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Bank   information   </td>
#     <td class="tg-0pky">   <br>other_installment_plans   </td>
#     <td class="tg-0pky">   <br>categorical   </td>
#     <td class="tg-0pky">   <br>Type of installments plans the   borrower already has   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Bank   information   </td>
#     <td class="tg-0pky">   <br>savings_account_status   </td>
#     <td class="tg-0pky">   <br>categorical   </td>
#     <td class="tg-0pky">   <br>Status of the saving account   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Collateral/Guarantor   </td>
#     <td class="tg-0pky">   <br>property   </td>
#     <td class="tg-0pky">   <br>categorical   </td>
#     <td class="tg-0pky">   <br>Type of valuable assets the   borrower owns   </td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">   <br>Collateral/Guarantor   </td>
#     <td class="tg-0pky">   <br>other_debtors   </td>
#     <td class="tg-0pky">   <br>categorical   </td>
#     <td class="tg-0pky">   <br>Indicate if someone else will be   involved in the repayment or is guaranteeing the loan   </td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# 1. El banco sospecha que entre mas pasa el tiempo más díficil es que puedan pagar los clientes que se les concedió un préstamo.
#
# a) Calcula el promedio del monto del préstamo de los que pagaron y el promedio del monto de los que no han pagado.
#
# b) Ajusta un modelo weibull y un modelo log-normal y graficas las funciones de riesgo respectivas.

# %%
pay=base[base['full_repaid']==1]
prompay=round(pay['amount'].mean(),2)
print(f' La cantidad de {promnopay} es el monto promedio de prestamo respecto a los clientes que pagaron\n')
nopay=base[base['full_repaid']==0]
promnopay=round(nopay['amount'].mean(),2)
print(f' La cantidad de {promnopay} es el monto promedio de prestamo respecto a los clientes que no han pagado')
# Out:
#  La cantidad de 3938.13 es el monto promedio de prestamo respecto a los clientes que pagaron
#
#  La cantidad de 3938.13 es el monto promedio de prestamo respecto a los clientes que no han pagado

# %%
from lifelines import WeibullFitter

weib_base = WeibullFitter().fit(base["duration"], base["full_repaid"])
weib_base.plot_hazard()
plt.title('Grafico de funcion de riesgo Weibull')
plt.xlabel("Months")
plt.show()

# %%
from lifelines import LogNormalFitter

log_base=LogNormalFitter().fit(base['duration'],base['full_repaid'])
log_base.plot_hazard()
plt.title('Grafico de funcion de riesgo LogNormal')
plt.xlabel('Months')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# c) comenta que significa la grafica de la función de riesgo de la weibull respecto a si los clientes tardan en pagar

# %% [markdown]
# Notese que acorde al grafico de la funcionde riesgo weibull, es interpretable que conforme avanza el tiempo, la probabilidad de que el credito que se les otrogo a los clientes sea pagado de vuelta, incrmenta.

# %% [markdown]
# d) comenta que significa la grafica de la función de riesgo de la log-normal respecto a si los clientes tardan en pagar

# %% [markdown]
# Observando el grafico de la funcion de riesgo log-normal, se destaca que a medida que avanza el tiempo, en primera instancia la probabilidad de que el credito que se les otrogo a los clientes sea pagado de vuelta, incrmenta bruscamente, sin embargo entrando en el intervalo de tiempo (20,30), se observa una suave decadencia en dicha probabilidad.

# %% [markdown]
# 2. Estima la función de supervivencia por el método de Kaplan-Meier para el tiempo que tardan los clientes en pagar y muestra su gráfica correspondiente

# %%
from lifelines import KaplanMeierFitter
km_base=KaplanMeierFitter().fit(base['duration'],base['full_repaid'])
km_base.survival_function_
# Out:
#           KM_estimate
# timeline
# 0.0          1.000000
# 4.0          0.994000
# 5.0          0.993000
# 6.0          0.927000
# 7.0          0.921951
# 8.0          0.915892
# 9.0          0.880510
# 10.0         0.854824
# 11.0         0.845544
# 12.0         0.711494
# 13.0         0.707054
# 14.0         0.703724
# 15.0         0.645914
# 16.0         0.644779
# 18.0         0.564040
# 20.0         0.555343
# 21.0         0.529195
# 22.0         0.526650
# 24.0         0.363821
# 26.0         0.362239
# 27.0         0.349585
# 28.0         0.346348
# 30.0         0.302445
# 33.0         0.298948
# 36.0         0.218056
# 39.0         0.208031
# 40.0         0.208031
# 42.0         0.187485
# 45.0         0.184806
# 47.0         0.181963
# 48.0         0.125100
# 54.0         0.117281
# 60.0         0.058640
# 72.0         0.058640

# %%
km_base.plot_survival_function(label= 'Funcion de Riesgo')
plt.title('KaplanMeier')
plt.show()

# %% [markdown]
# 3. Coloca la gráfica de kaplan Meier sobre la grafica de supervivencia log-normal

# %%
km_base.plot_survival_function(label='KaplanMeier')
log_base.plot_survival_function(label='LogNormal')
plt.title('KaplanMeier vs LogNormal')
plt.xlabel('Months')
plt.show()

# %% [markdown]
# 4. Comenta si las graficas se parecen o no, y en que se diferencian

# %% [markdown]
# Las graficas si son muy parecidas en cuanto a tendencias de sus respectivas funciones, tienen cierta variacion pero es debido a que kaplanmeier es de tipo discreta y lognormal de tipo continua

# %% [markdown]
# 5. El banco considera que los que piden préstado una gran cantidad de dinero en realidad nunca piensa pagar
#
# a) calcula la mediana de la cantidad que pidieron prestado (amount of money borrowed), asigna un 1 a quienes se encuentran igual o arriba de la mediana (deben mucho) y 0 a los que se encuentran debajo de la mediana (deben poco)
#
# b) Elabora y grafica juntas las funciones de supervivencia por el método de Kaplan-Meier para los que deben mucho y para los que deben poco.
#
# c)Interpreta las graficas de supervivencia, ¿qué significan? ¿quién paga más rápido? ¿quién tarda en pagar más?
#
# d)Elabora un log-rank test para comprobar si las funciones de supervivencia de los que deben mucho y los que deben poco son distintas, e interpreta el resultado de la prueba
#
# e) ¿el banco tenía razón? Explique

# %% [markdown]
# ## a)

# %%
mediana = base['amount'].median()
print(f'La cantidad de {mediana} es la mediana de los prestamos otorgados a los clientes')
# Out:
# La cantidad de 2319.5 es la mediana de los prestamos otorgados a los clientes

# %%
base['ArribaDeMediana'] = np.where(base['amount'] >= mediana, 1, 0)
base.head()
# Out:
#   checking_account_status  duration        credit_history  \
# 0                 below_0         6      critical_account
# 1                0_to_200        48  existing_credit_paid
# 2              no_account        12      critical_account
# 3                 below_0        42  existing_credit_paid
# 4                 below_0        24       delay_in_paying
#
#                purpose  amount savings_account_status employment_years  \
# 0             radio_TV    1169                unknown          above_7
# 1             radio_TV    5951              below_100      between_1_4
# 2            education    2096              below_100      between_4_7
# 3  furniture_equipment    7882              below_100      between_4_7
# 4              car_new    4870              below_100      between_1_4
#
#    installment_rate personal_status other_debtors  ...  age  \
# 0                 4        M_single          None  ...   67
# 1                 2    F_not_single          None  ...   22
# ...

# %% [markdown]
# ## b)

# %%
arribamed=base.query('ArribaDeMediana==1')
km_arribamed=KaplanMeierFitter().fit(arribamed['duration'],arribamed['full_repaid'])

abajomed=base.query('ArribaDeMediana==0')
km_abajomed=KaplanMeierFitter().fit(abajomed['duration'],abajomed['full_repaid'])

km_arribamed.plot_survival_function(ci_show= False,label='Deben mucho')
km_abajomed.plot_survival_function(ci_show= False,label='Deben poco')
plt.show()

# %% [markdown]
# ## c)

# %% [markdown]
# Quienes deben poco (pidieron una cantidad prestada ubicada por debajo de la mediana) tienden a tardar menos en pagar, mientras que quienes deben mucho (pidieron una cantidad prestada ubicada por encima de la mediana) tienden a tardar mas en pagar. La diferencia en torno al tiempo empieza igualado, pero apenas comienza el tiempo 10, dicha igualacion se pierde, pasando a tener una diferencia de tiempo de poco ams de 20 meses, una vez que pasamos el tiempo 15 aproximadamente.

# %% [markdown]
# ## d)

# %%
from lifelines.statistics import logrank_test

lrt = logrank_test(abajomed['duration'], abajomed['full_repaid'], arribamed['duration'], arribamed['full_repaid'])
lrt.print_summary()
# Out:
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic      p  -log2(p)
#          552.91 <0.005    403.72

# %% [markdown]
# **Ho: La duración de pago de los que deben mucho y poco es la mismo.**
#
# **Ha: La duración de pago de los que deben mucho y poco es distinta.**

# %% [markdown]
# Observamos que el p-value es menor a 0.005, por lo que entendemos que estadisticamente, debemos rechazar Ho, en otras palabras, la duracion de pago de los que deben mucho y deben poco, NO es la misma.

# %% [markdown]
# ## e)

# %% [markdown]
# Puede afirmarse que el banco **NO** tenia razon, puesto que en principio si, demoran mas en pagar las personas que adquirieron un prestamo de mayor volumnen, sin embargo, no tardan mas en pagar porque no quieran pagar, si no que, hay diveros motivos para ello, un ejemplo seria que al ser una cantidad mas grande de prestamo a pagar por parte de las personas, podria requerirse de mas tiempo para juntar el capital a devolver.

# %% [markdown]
# 6. Elige seis variables para ajustar un modelo de cox de riesgos porporcionales. Antes de correr el modelo explica en qué sentido y por qué afectan el riesgo de pagar el préstamo cada una de las variables elegidas

# %%
from lifelines import CoxPHFitter

# %% [markdown]
# **1. credit_history:** Para conocer que tan riesgoso sera otorgar un credito o no a un tercero, estrictamente se requiere conocer su historial crediticio. Variable dummy = 'critical_account'.
#
# **2. amount:** La cantidad de prestamo es inportante, ya que puede que si es muy grande, no se pueda tener de vuelta la cantidad de dinero prestada.
#
# **3. purpose:** Conocer el motivo del prestamo nos da una idea mas certera del proposito de otorgar dicho prestamo. Variable dummy= 'education'.
#
# **4. age:** La edad de alguien no adulto, puede ser financieramente inestable.
#
# **5. savings_account_status:** Al tener conocimiento sobre los fondos de ahorro del prestatario, nos hara saber como es el comportamiento financiero del mencionado. Variable dummy= 'below_100'.
#
# **6. property:** Contar con bienes, concede un aseguramiento economico mayor.. Variable dummy= 'no_property'.

# %%
ch = base[['duration', 'credit_history', 'full_repaid']]
ch['C.A.'] = np.where(base['credit_history'] == 'critical_account', 1, 0)
ch = ch.drop(['credit_history'], axis = 1)

cox_ch = CoxPHFitter().fit(ch, 'duration', 'full_repaid')
cox_ch.print_summary()
# Out:
# C:\Users\alan0\AppData\Local\Temp\ipykernel_65492\1605189658.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ch['C.A.'] = np.where(base['credit_history'] == 'critical_account', 1, 0)
# <lifelines.CoxPHFitter: fitted with 1000 total observations, 300 right-censored observations>
#              duration col = 'duration'
#                 event col = 'full_repaid'
#       baseline estimation = breslow
#    number of observations = 1000
# number of events observed = 700
#    partial log-likelihood = -4256.12
#          time fit was run = 2023-04-05 04:27:35 UTC
#
# ---
#             coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# ...

# %%
amount = base[['duration', 'amount', 'full_repaid']]

cox_amount = CoxPHFitter().fit(amount, 'duration', 'full_repaid')
cox_amount.print_summary()
# Out:
# <lifelines.CoxPHFitter: fitted with 1000 total observations, 300 right-censored observations>
#              duration col = 'duration'
#                 event col = 'full_repaid'
#       baseline estimation = breslow
#    number of observations = 1000
# number of events observed = 700
#    partial log-likelihood = -4124.50
#          time fit was run = 2023-04-05 04:27:35 UTC
#
# ---
#             coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# amount     -0.00       1.00       0.00            -0.00            -0.00                 1.00                 1.00
#
#             cmp to      z      p   -log2(p)
# covariate
# amount        0.00 -14.03 <0.005     146.03
# ---
# Concordance = 0.73
# Partial AIC = 8250.99
# log-likelihood ratio test = 289.78 on 1 df
# -log2(p) of ll-ratio test = 213.45

# %%
purpose=base[['duration', 'purpose', 'full_repaid']]
purpose['Education']=np.where(base['purpose']=='education', 1, 0)
purpose=purpose.drop(['purpose'], axis=1)

cox_purpose=CoxPHFitter().fit(purpose, 'duration', 'full_repaid')
cox_purpose.print_summary()
# Out:
# C:\Users\alan0\AppData\Local\Temp\ipykernel_65492\2417629260.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purpose['Education']=np.where(base['purpose']=='education', 1, 0)
# <lifelines.CoxPHFitter: fitted with 1000 total observations, 300 right-censored observations>
#              duration col = 'duration'
#                 event col = 'full_repaid'
#       baseline estimation = breslow
#    number of observations = 1000
# number of events observed = 700
#    partial log-likelihood = -4268.40
#          time fit was run = 2023-04-05 04:27:36 UTC
#
# ---
#             coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# ...

# %%
age = base[['duration', 'age', 'full_repaid']]

cox_age = CoxPHFitter().fit(age, 'duration', 'full_repaid')
cox_age.print_summary()
# Out:
# <lifelines.CoxPHFitter: fitted with 1000 total observations, 300 right-censored observations>
#              duration col = 'duration'
#                 event col = 'full_repaid'
#       baseline estimation = breslow
#    number of observations = 1000
# number of events observed = 700
#    partial log-likelihood = -4266.36
#          time fit was run = 2023-04-05 04:27:37 UTC
#
# ---
#             coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# age         0.01       1.01       0.00             0.00             0.01                 1.00                 1.01
#
#             cmp to    z    p   -log2(p)
# covariate
# age           0.00 2.49 0.01       6.31
# ---
# Concordance = 0.54
# Partial AIC = 8534.72
# log-likelihood ratio test = 6.05 on 1 df
# -log2(p) of ll-ratio test = 6.17

# %%
sa = base[['duration', 'savings_account_status', 'full_repaid']]
sa['S.A.'] = np.where(base['savings_account_status'] == 'below_100', 1, 0)
sa = sa.drop(['savings_account_status'], axis = 1)

cox_sa = CoxPHFitter().fit(sa, 'duration', 'full_repaid')
cox_sa.print_summary()
# Out:
# C:\Users\alan0\AppData\Local\Temp\ipykernel_65492\2078253228.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sa['S.A.'] = np.where(base['savings_account_status'] == 'below_100', 1, 0)
# <lifelines.CoxPHFitter: fitted with 1000 total observations, 300 right-censored observations>
#              duration col = 'duration'
#                 event col = 'full_repaid'
#       baseline estimation = breslow
#    number of observations = 1000
# number of events observed = 700
#    partial log-likelihood = -4267.18
#          time fit was run = 2023-04-05 04:27:37 UTC
#
# ---
#             coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# ...

# %%
property = base[['duration', 'full_repaid', 'property']]
property['N.P.'] = np.where(base['property'] == 'no_property', 1, 0)
property=property.drop(['property'], axis=1) 

cox_property = CoxPHFitter().fit(property, 'duration', 'full_repaid')
cox_property.print_summary()
# Out:
# C:\Users\alan0\AppData\Local\Temp\ipykernel_65492\4172271340.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   property['N.P.'] = np.where(base['property'] == 'no_property', 1, 0)
# <lifelines.CoxPHFitter: fitted with 1000 total observations, 300 right-censored observations>
#              duration col = 'duration'
#                 event col = 'full_repaid'
#       baseline estimation = breslow
#    number of observations = 1000
# number of events observed = 700
#    partial log-likelihood = -4247.27
#          time fit was run = 2023-04-05 04:27:38 UTC
#
# ---
#             coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# ...

# %% [markdown]
# 7. Interpreta la regresión de Cox

# %% [markdown]
# **1. credit_history:** Para este caso particular, se tiene un p value inferior a 0.005, es decir, menor a 0.05 (valor de nuestro alpha), por lo que si afecta el historial crediticio del cliente.
#
# **2. amount:** Para este caso particular, se tiene un p value inferior a 0.005, es decir, menor a 0.05 (valor de nuestro alpha), por lo que si afecta la cantidad de credito que se le otorgara al cliente.
#
# **3. purpose:** Para este caso particular, se tiene un p value de 0.18, es decir, mayor a 0.05 (valor de nuestro alpha), por lo que no afecta el proposito por el que solicita un prestamo nuestro cliente.
#
# **4. age:** Para este caso particular, se tiene un p value de 0.01, es decir, menor a 0.05 (valor de nuestro alpha), por lo que si afecta la edad de nuestro cliente.
#
# **5. savings_account_status:** Para este caso particular, se tiene un p value de 0.04, es decir, menor a 0.05 (valor de nuestro alpha), por lo que si importa el fondo de ahorro de nuestro cliente, aunque no de manera muy relevante, al menos estadisticamente hablando.
#
# **6. property:** Para este caso particular, se tiene un p value inferior a 0.005, es decir, menor a 0.05 (valor de nuestro alpha), por lo que si afecta el hecho de contar con bienes o no.

# %% [markdown]
# 8. Con base en el análisis hecho hasta ahora qué recomendación podría hacer al banco para mejorar sus políticas de préstamo

# %% [markdown]
# No admitir o otorgar prestamos minimos a cualquier persona, sino que al realizar dicha accion de ceder un credito, se tomen en cuenta los siguientes cirterios:
#
# 1. Historial crediticio (Cuenta critica).
# 2. Edad y cantidad de credito (no muy jovenes para cantidades grandes).
# 3. La cantidad de bienes que se posee.
#
# Asimismo, tener como ultimo recurso a verificar, los fondos de ahorro del cliente, pero sin tomarlo como un factor determinante, mas bien, como una informacion adicional.
