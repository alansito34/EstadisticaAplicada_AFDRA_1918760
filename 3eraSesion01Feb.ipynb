# %% [markdown]
# # Estadistica Aplicada

# %% [markdown]
# ## Alan Fernando Del Real Almaguer

# %% [markdown]
# **3er Sesión 01 de Enero 2023**

# %% [markdown]
# ### Tuplas

# %% [markdown]
# Es una coleccion de objetos inmutables (que no se pueden contar)

# %%
tupla1=("Juan","Miguel",23)

# %%
tupla1
# Out:
# ('Juan', 'Miguel', 23)

# %% [markdown]
# ### Diccionarios

# %%
estadistica_g5={"Nombre":["Juan","Jaime","Ale"],"Edad":[17,22,15]}
estadistica_g5
# Out:
# {'Nombre': ['Juan', 'Jaime', 'Ale'], 'Edad': [17, 22, 15]}

# %%
estadistica_g5.keys()
# Out:
# dict_keys(['Nombre', 'Edad'])

# %%
estadistica_g5.values()
# Out:
# dict_values([['Juan', 'Jaime', 'Ale'], [17, 22, 15]])

# %%
estadistica_g5["Nombre"]
# Out:
# ['Juan', 'Jaime', 'Ale']

# %% [markdown]
# # Pandas

# %%
import numpy as np
import pandas as pd

# %%
alumno1=["Juan","Perez", 23]
alumno2=["Ale","Solis", 23]
alumno3=["Jime","Garza", 23]
alumno4=["Raul","Lara", 23]

# %%
estadistica=[alumno1,alumno2,alumno3,alumno4]

# %%
estadistica
# Out:
#   Nombre Apellido  Edad
# 0   Juan    Perez    23
# 1    Ale    Solis    23
# 2   Jime    Garza    23
# 3   Raul     Lara    23

# %%
# vamos a convertirla em dataframe
estadistica= pd.DataFrame(estadistica,columns=["Nombre","Apellido","Edad"])

# %%
estadistica.columns
# Out:
# Index(['Nombre', 'Apellido', 'Edad'], dtype='object')

# %%
estadistica.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
estadistica["Edad en dias"] = estadistica["Edad"]*365
estadistica
# Out:
#   Nombre Apellido  Edad  Edad en dias
# 0   Juan    Perez    23          8395
# 1    Ale    Solis    23          8395
# 2   Jime    Garza    23          8395
# 3   Raul     Lara    23          8395

# %%
estadistica["Origen"]=["Apodaca","Escobedo","San Pedro","Montemorelos"]
estadistica
# Out:
#   Nombre Apellido  Edad  Edad en dias        Origen
# 0   Juan    Perez    23          8395       Apodaca
# 1    Ale    Solis    23          8395      Escobedo
# 2   Jime    Garza    23          8395     San Pedro
# 3   Raul     Lara    23          8395  Montemorelos

# %%
estadistica["Edad"]
# Out:
# 0    23
# 1    23
# 2    23
# 3    23
# Name: Edad, dtype: int64

# %%
estadistica[["Nombre","Edad"]]
estadistica
# Out:
#   Nombre Apellido  Edad  Edad en dias        Origen
# 0   Juan    Perez    23          8395       Apodaca
# 1    Ale    Solis    23          8395      Escobedo
# 2   Jime    Garza    23          8395     San Pedro
# 3   Raul     Lara    23          8395  Montemorelos

# %%
estadistica[0:2]
# Out:
#   Nombre Apellido  Edad  Edad en dias    Origen
# 0   Juan    Perez    23          8395   Apodaca
# 1    Ale    Solis    23          8395  Escobedo

# %%
estadistica[0:2][["Nombre","Edad"]]
# Out:
#   Nombre  Edad
# 0   Juan    23
# 1    Ale    23

# %%
estadistica.iloc[:,[0,2]]
# Out:
#   Nombre  Edad
# 0   Juan    23
# 1    Ale    23
# 2   Jime    23
# 3   Raul    23

# %%
estadistica.iloc[0,[0,2]]
# Out:
# Nombre    Juan
# Edad        23
# Name: 0, dtype: object

# %%
estadistica.loc[:,"Apellido"]
# Out:
# 0    Perez
# 1    Solis
# 2    Garza
# 3     Lara
# Name: Apellido, dtype: object

# %%
estadistica.loc[:,["Nombre","Apellido"]]
# Out:
#   Nombre Apellido
# 0   Juan    Perez
# 1    Ale    Solis
# 2   Jime    Garza
# 3   Raul     Lara

# %%
estadistica.Nombre
# Out:
# 0    Juan
# 1     Ale
# 2    Jime
# 3    Raul
# Name: Nombre, dtype: object

# %%
estadistica_g5
# Out:
# {'Nombre': ['Juan', 'Jaime', 'Ale'], 'Edad': [17, 22, 15]}

# %%
estadistica_g5=pd.DataFrame(estadistica_g5)
estadistica_g5
# Out:
#   Nombre  Edad
# 0   Juan    17
# 1  Jaime    22
# 2    Ale    15

# %%
example=pd.read_excel("C:/Users/LENOVO/Downloads/Actividad 3.5 Esperanzas de vida.xlsx")
example
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5  \
# 0         Edad   d(x,x+1)       s(x)         lx         NaN    Mediana
# 1            0      15270     100000        NaN         NaN  45.125637
# 2            1       5253      84730    41.0087         NaN        NaN
# 3            2       2941      79477    40.1614         NaN        NaN
# 4            3       1929      76536   39.36663         NaN        NaN
# ..         ...        ...        ...        ...         ...        ...
# 98          97         31         86    0.50195         NaN        NaN
# 99          98         21         55    0.50109         NaN        NaN
# 100         99         14         34    0.50054         NaN        NaN
# 101        100        NaN         20     0.5002         NaN        NaN
# 102        NaN      99980    4050870        NaN         NaN        NaN
#
#     Unnamed: 6
# 0         Moda
# 1           75
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# ...

# %%
calificiones=pd.read_csv("https://raw.githubusercontent.com/jimmyzac/Estadistica-Aplicada-FCFM-UANL/main/bases_datos/Calificaciones.csv")
calificiones
# Out:
#     Id            Nombre   Apellido  Calficación Final
# 0    1           ANTONIO     GARCIA                 73
# 1    2            MANUEL  FERNANDEZ                 19
# 2    3              JOSE   GONZALEZ                 38
# 3    4             DAVID      PEREZ                 14
# 4    5              JUAN      LOPEZ                 99
# 5    6      JOSE ANTONIO  RODRIGUEZ                 66
# 6    7            JAVIER    SANCHEZ                 46
# 7    8         JOSE LUIS      GOMEZ                 89
# 8    9  FRANCISCO JAVIER    JIMENEZ                 10
# 9   10            CARLOS       RUIZ                 62
# 10  11             JESUS     ALONSO                 94
# 11  12         ALEJANDRO  HERNANDEZ                 17
# 12  13            MIGUEL       DIAZ                 85
# 13  14       JOSE MANUEL  GUTIERREZ                 34
# 14  15            RAFAEL    ALVAREZ                 86
# 15  16      MIGUEL ANGEL     MORENO                100
# ...

# %%
calificiones.head(10)
# Out:
#    Id            Nombre   Apellido  Calficación Final
# 0   1           ANTONIO     GARCIA                 73
# 1   2            MANUEL  FERNANDEZ                 19
# 2   3              JOSE   GONZALEZ                 38
# 3   4             DAVID      PEREZ                 14
# 4   5              JUAN      LOPEZ                 99
# 5   6      JOSE ANTONIO  RODRIGUEZ                 66
# 6   7            JAVIER    SANCHEZ                 46
# 7   8         JOSE LUIS      GOMEZ                 89
# 8   9  FRANCISCO JAVIER    JIMENEZ                 10
# 9  10            CARLOS       RUIZ                 62

# %%
#calificiones.tail(10)
# Out:
#     Id       Nombre   Apellido  Calficación Final
# 18  19        ANGEL        GIL                100
# 19  20       SERGIO    AGUIRRE                  2
# 20  21   JOSE MARIA       DIEZ                 29
# 21  22     FERNANDO    SALAZAR                 51
# 22  23        JORGE      RAMOS                 76
# 23  24         LUIS  DOMINGUEZ                 12
# 24  25      ALBERTO      ORTIZ                 99
# 25  26  JUAN CARLOS     IBAÑEZ                 43
# 26  27       ALVARO    RAMIREZ                 40
# 27  28       ADRIAN       SAEZ                  7

# %%
# shape nos dice cuantas filas y columnas tiene
calificiones.shape
# Out:
# (28, 4)

# %%
calificiones.columns
# Out:
# Index(['Id', 'Nombre', 'Apellido', 'Calficación Final'], dtype='object')

# %%
calificiones.index
# Out:
# RangeIndex(start=0, stop=28, step=1)

# %%
calificiones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Id                 28 non-null     int64
#  1   Nombre             28 non-null     object
#  2   Apellido           28 non-null     object
#  3   Calficación Final  28 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 1.0+ KB

# %%
calificiones.describe
# Out:
# <bound method NDFrame.describe of     Id            Nombre   Apellido  Calficación Final
# 0    1           ANTONIO     GARCIA                 73
# 1    2            MANUEL  FERNANDEZ                 19
# 2    3              JOSE   GONZALEZ                 38
# 3    4             DAVID      PEREZ                 14
# 4    5              JUAN      LOPEZ                 99
# 5    6      JOSE ANTONIO  RODRIGUEZ                 66
# 6    7            JAVIER    SANCHEZ                 46
# 7    8         JOSE LUIS      GOMEZ                 89
# 8    9  FRANCISCO JAVIER    JIMENEZ                 10
# 9   10            CARLOS       RUIZ                 62
# 10  11             JESUS     ALONSO                 94
# 11  12         ALEJANDRO  HERNANDEZ                 17
# 12  13            MIGUEL       DIAZ                 85
# 13  14       JOSE MANUEL  GUTIERREZ                 34
# 14  15            RAFAEL    ALVAREZ                 86
# ...

# %%
calificiones.set_index("Apellido")
# Out:
#            Id            Nombre  Calficación Final
# Apellido
# GARCIA      1           ANTONIO                 73
# FERNANDEZ   2            MANUEL                 19
# GONZALEZ    3              JOSE                 38
# PEREZ       4             DAVID                 14
# LOPEZ       5              JUAN                 99
# RODRIGUEZ   6      JOSE ANTONIO                 66
# SANCHEZ     7            JAVIER                 46
# GOMEZ       8         JOSE LUIS                 89
# JIMENEZ     9  FRANCISCO JAVIER                 10
# RUIZ       10            CARLOS                 62
# ALONSO     11             JESUS                 94
# HERNANDEZ  12         ALEJANDRO                 17
# DIAZ       13            MIGUEL                 85
# GUTIERREZ  14       JOSE MANUEL                 34
# ALVAREZ    15            RAFAEL                 86
# MORENO     16      MIGUEL ANGEL                100
# MUÑOZ      17             PEDRO                  1
# ...

# %%
calificiones.rename(columns={"Calficación Final":"cal_final","Nombre":"nombre","Id":"id","Apellido":"apellido"},inplace=True)
calificiones.head(11)
# Out:
#     id            nombre   apellido  cal_final
# 0    1           ANTONIO     GARCIA         73
# 1    2            MANUEL  FERNANDEZ         19
# 2    3              JOSE   GONZALEZ         38
# 3    4             DAVID      PEREZ         14
# 4    5              JUAN      LOPEZ         99
# 5    6      JOSE ANTONIO  RODRIGUEZ         66
# 6    7            JAVIER    SANCHEZ         46
# 7    8         JOSE LUIS      GOMEZ         89
# 8    9  FRANCISCO JAVIER    JIMENEZ         10
# 9   10            CARLOS       RUIZ         62
# 10  11             JESUS     ALONSO         94

# %%
mean=calificiones["cal_final"].mean()
mean
# Out:
# 52.0

# %%
calificiones["situacion"]=np.where(calificiones["cal_final"]>=70,"Aprobado","Reprobado")
calificiones
# Out:
#     id            nombre   apellido  cal_final  situacion
# 0    1           ANTONIO     GARCIA         73   Aprobado
# 1    2            MANUEL  FERNANDEZ         19  Reprobado
# 2    3              JOSE   GONZALEZ         38  Reprobado
# 3    4             DAVID      PEREZ         14  Reprobado
# 4    5              JUAN      LOPEZ         99   Aprobado
# 5    6      JOSE ANTONIO  RODRIGUEZ         66  Reprobado
# 6    7            JAVIER    SANCHEZ         46  Reprobado
# 7    8         JOSE LUIS      GOMEZ         89   Aprobado
# 8    9  FRANCISCO JAVIER    JIMENEZ         10  Reprobado
# 9   10            CARLOS       RUIZ         62  Reprobado
# 10  11             JESUS     ALONSO         94   Aprobado
# 11  12         ALEJANDRO  HERNANDEZ         17  Reprobado
# 12  13            MIGUEL       DIAZ         85   Aprobado
# 13  14       JOSE MANUEL  GUTIERREZ         34  Reprobado
# 14  15            RAFAEL    ALVAREZ         86   Aprobado
# ...

# %%
calificiones.head()
# Out:
#    id   nombre   apellido  cal_final  situacion
# 0   1  ANTONIO     GARCIA         73   Aprobado
# 1   2   MANUEL  FERNANDEZ         19  Reprobado
# 2   3     JOSE   GONZALEZ         38  Reprobado
# 3   4    DAVID      PEREZ         14  Reprobado
# 4   5     JUAN      LOPEZ         99   Aprobado

# %%
calificiones.groupby("situacion").count()["cal_final"]
# Out:
# situacion
# Aprobado     10
# Reprobado    18
# Name: cal_final, dtype: int64

# %%
calificiones.groupby("situacion").mean()["cal_final"]
# Out:
# situacion
# Aprobado     90.100000
# Reprobado    30.833333
# Name: cal_final, dtype: float64

# %%
excelentes=calificiones[calificiones["cal_final"]>=90]
excelentes
# Out:
#     id        nombre apellido  cal_final situacion
# 4    5          JUAN    LOPEZ         99  Aprobado
# 10  11         JESUS   ALONSO         94  Aprobado
# 15  16  MIGUEL ANGEL   MORENO        100  Aprobado
# 18  19         ANGEL      GIL        100  Aprobado
# 24  25       ALBERTO    ORTIZ         99  Aprobado

# %%
calificiones.value_counts("situacion")
# Out:
# situacion
# Reprobado    18
# Aprobado     10
# dtype: int64

# %%
calificiones.sort_values("cal_final",ascending=False)
# Out:
#     id            nombre   apellido  cal_final  situacion
# 18  19             ANGEL        GIL        100   Aprobado
# 15  16      MIGUEL ANGEL     MORENO        100   Aprobado
# 24  25           ALBERTO      ORTIZ         99   Aprobado
# 4    5              JUAN      LOPEZ         99   Aprobado
# 10  11             JESUS     ALONSO         94   Aprobado
# 7    8         JOSE LUIS      GOMEZ         89   Aprobado
# 14  15            RAFAEL    ALVAREZ         86   Aprobado
# 12  13            MIGUEL       DIAZ         85   Aprobado
# 22  23             JORGE      RAMOS         76   Aprobado
# 0    1           ANTONIO     GARCIA         73   Aprobado
# 5    6      JOSE ANTONIO  RODRIGUEZ         66  Reprobado
# 17  18             PABLO     BLANCO         64  Reprobado
# 9   10            CARLOS       RUIZ         62  Reprobado
# 21  22          FERNANDO    SALAZAR         51  Reprobado
# 6    7            JAVIER    SANCHEZ         46  Reprobado
# ...

# %%
calificiones=calificiones.sort_values(["apellido","nombre"],ascending=[True,True])
calificiones
# Out:
#     id            nombre   apellido  cal_final  situacion
# 19  20            SERGIO    AGUIRRE          2  Reprobado
# 10  11             JESUS     ALONSO         94   Aprobado
# 14  15            RAFAEL    ALVAREZ         86   Aprobado
# 17  18             PABLO     BLANCO         64  Reprobado
# 12  13            MIGUEL       DIAZ         85   Aprobado
# 20  21        JOSE MARIA       DIEZ         29  Reprobado
# 23  24              LUIS  DOMINGUEZ         12  Reprobado
# 1    2            MANUEL  FERNANDEZ         19  Reprobado
# 0    1           ANTONIO     GARCIA         73   Aprobado
# 18  19             ANGEL        GIL        100   Aprobado
# 7    8         JOSE LUIS      GOMEZ         89   Aprobado
# 2    3              JOSE   GONZALEZ         38  Reprobado
# 13  14       JOSE MANUEL  GUTIERREZ         34  Reprobado
# 11  12         ALEJANDRO  HERNANDEZ         17  Reprobado
# 25  26       JUAN CARLOS     IBAÑEZ         43  Reprobado
# ...
